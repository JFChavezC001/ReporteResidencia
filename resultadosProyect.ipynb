# %% [markdown]
# # Resultados
# ### Mostraremos los resultados adicionales a esta investigación

# %% [markdown]
# ## Superficie sembrada del año 2000

# %%
import pandas as pd

# %%
#creamos nuestras listas de datos que posteriormente transformaremos en un solo dataframe
FrijolPV=["Frijol","primavera-verano",741,21217.5]
FrijolOI=["Frijol","otoño-invierno", 168, ]
MFPV=["Maíz Forrajero","primavera-verano",7288,15395]
MFOI=["Maíz Forrajero","otoño-invierno",20,]
MGPV=["Maíz de Grano","primavera-verano",100612,487389]
MGOI=["Maíz de Grano","otoño-invierno",461,]

# %%
supSembrada=[FrijolPV,FrijolOI,MFPV,MFOI,MGPV,MGOI]

# %%
#Creamos el DF a traves de los datos de nuestras listas
supSemb=pd.DataFrame(supSembrada,columns=['Cultivo','Ciclo productivo','Superficie Sembrada(ha)/Modalidad Riego','Superficie Sembrada(ha)/Modalidad Temporal'])
supSemb
# Out:
#           Cultivo  Ciclo productivo  Superficie Sembrada(ha)/Modalidad Riego  \
# 0          Frijol  primavera-verano                                      741
# 1          Frijol    otoño-invierno                                      168
# 2  Maíz Forrajero  primavera-verano                                     7288
# 3  Maíz Forrajero    otoño-invierno                                       20
# 4   Maíz de Grano  primavera-verano                                   100612
# 5   Maíz de Grano    otoño-invierno                                      461
#
#    Superficie Sembrada(ha)/Modalidad Temporal
# 0                                     21217.5
# 1                                         NaN
# 2                                     15395.0
# 3                                         NaN
# 4                                    487389.0
# 5                                         NaN
